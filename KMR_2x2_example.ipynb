# %%
# %matplotlib inline

# %%
from __future__ import division
from KMR_2x2 import KMR_2x2

# %%
p = 1/3
N = 6
epsilon = 0.1
T = 10**7

# %%
kmr = KMR_2x2(N, p, epsilon)

# %%
kmr.simulate(T)  # Takes about 1 min on my computer

# %%
kmr.plot_sample_path()

# %%
kmr.plot_emprical_dist()

# %%
kmr.compute_stationary_dist()
kmr.plot_stationary_dist()

# %%
kmr.set_epsilon(0.001)

# %%
kmr.simulate(T)  # Takes about 1 min on my computer

# %%
kmr.plot_sample_path()

# %%
kmr.plot_emprical_dist()

# %%
kmr.compute_stationary_dist()
kmr.plot_stationary_dist()
