# %%
# %matplotlib inline

# %%
from __future__ import division
from KMR_2x2 import KMR_2x2

# %%
p = 1/3
N = 10
epsilon = 0.03
T = 500000

# %%
kmr = KMR_2x2(N, p, epsilon)

# %%
kmr.simulate(T)

# %%
kmr.plot_sample_path()

# %%
kmr.plot_emprical_distribution()

# %%
kmr.set_epsilon(0.02)

# %%
kmr.simulate(T)

# %%
kmr.plot_sample_path()

# %%
kmr.plot_emprical_distribution()
