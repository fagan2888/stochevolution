# %%
include("kmr.jl");

# %%
using PyPlot
using StatsBase

# %%
p = 1/3
N = 10
epsilon = 0.01
ts_length = 10^8;

# %%
kmr = KMR2x2(p, N, epsilon);

# %%
@time simulate(kmr, ts_length, init=0);
@time simulate(kmr, ts_length, init=0);
@time simulate(kmr, ts_length, init=0);
# Out:
#   7.468345 seconds (100.36 M allocations: 2.251 GB, 1.55% gc time)
#   7.236473 seconds (100.00 M allocations: 2.235 GB, 1.54% gc time)
#   7.309372 seconds (100.00 M allocations: 2.235 GB, 1.92% gc time)

# %%
x = simulate(kmr, ts_length, init=0);

# %%
fig, ax = subplots()
ax[:plot](x, alpha=0.5)
ax[:set_ylim](0, kmr.N)
ax[:set_title]("Sample path: \$\\varepsilon = $(kmr.epsilon)\$")
ax[:set_xlabel]("Time")
ax[:set_ylabel]("State")
plt[:show]()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3288e3668>)

# %%
fig, ax = subplots()
h = fit(Histogram, x, 0:kmr.N+1, closed=:left)
ax[:bar](0:kmr.N, h.weights, align="center")
ax[:set_title]("Empirical distribution: \$\\varepsilon = $(kmr.epsilon)\$")
ax[:set_xlim](-0.5, kmr.N+0.5)
ax[:set_xlabel]("State")
ax[:set_ylabel]("Frequency")
plt[:show]()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x328b78d68>)

# %%
epsilon!(kmr, 0.005);

# %%
x = simulate(kmr, ts_length, init=0);

# %%
fig, ax = subplots()
ax[:plot](x, alpha=0.5)
ax[:set_ylim](0, kmr.N)
ax[:set_title]("Sample path: \$\\varepsilon = $(kmr.epsilon)\$")
ax[:set_xlabel]("Time")
ax[:set_ylabel]("State")
plt[:show]()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x328cb8668>)

# %%
fig, ax = subplots()
h = fit(Histogram, x, 0:kmr.N+1, closed=:left)
ax[:bar](0:kmr.N, h.weights, align="center")
ax[:set_title]("Empirical distribution: \$\\varepsilon = $(kmr.epsilon)\$")
ax[:set_xlim](-0.5, kmr.N+0.5)
ax[:set_xlabel]("State")
ax[:set_ylabel]("Frequency")
plt[:show]()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x328db8c50>)
