# %%
include("kmr.jl");

# %%
using PyPlot
using StatsBase

# %%
p = 1/3
N = 10
epsilon = 0.01
ts_length = 10^8;

# %%
kmr = KMR2x2(p, N, epsilon);

# %%
@time simulation(kmr, ts_length, 0);
@time simulation(kmr, ts_length, 0);
@time simulation(kmr, ts_length, 0);
# Out:
#   6.769385 seconds (100.23 M allocations: 2.991 GB, 1.67% gc time)
#   6.718432 seconds (100.00 M allocations: 2.980 GB, 3.20% gc time)
#   6.772254 seconds (100.00 M allocations: 2.980 GB, 2.81% gc time)

# %%
x = simulation(kmr, ts_length, 0);

# %%
fig, ax = subplots()
ax[:plot](x, alpha=0.5)
ax[:set_ylim](0, kmr.N)
ax[:set_title]("Sample path: \$\\varepsilon = $(kmr.epsilon)\$")
ax[:set_xlabel]("Time")
ax[:set_ylabel]("State")
plt[:show]()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3155e13d0>)

# %%
fig, ax = subplots()
h = fit(Histogram, x, 0:kmr.N+1, closed=:left)
ax[:bar](0:kmr.N, h.weights, align="center")
ax[:set_title]("Emprical distribution: \$\\varepsilon = $(kmr.epsilon)\$")
ax[:set_xlim](-0.5, kmr.N+0.5)
ax[:set_xlabel]("State")
ax[:set_ylabel]("Frequency")
plt[:show]()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3155e1910>)

# %%
epsilon!(kmr, 0.005);

# %%
x = simulation(kmr, ts_length, 0);

# %%
fig, ax = subplots()
ax[:plot](x, alpha=0.5)
ax[:set_ylim](0, kmr.N)
ax[:set_title]("Sample path: \$\\varepsilon = $(kmr.epsilon)\$")
ax[:set_xlabel]("Time")
ax[:set_ylabel]("State")
plt[:show]()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x346765e10>)

# %%
fig, ax = subplots()
h = fit(Histogram, x, 0:kmr.N+1, closed=:left)
ax[:bar](0:kmr.N, h.weights, align="center")
ax[:set_title]("Emprical distribution: \$\\varepsilon = $(kmr.epsilon)\$")
ax[:set_xlim](-0.5, kmr.N+0.5)
ax[:set_xlabel]("State")
ax[:set_ylabel]("Frequency")
plt[:show]()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x347bb2850>)
